# %% [markdown]
# ## This Notebook has solved Multiple Linear Regression Problem through Manual Approach and Through Automated- Manual Combined approach to determine the best fit for the Given Data Set

# %% [markdown]
# ## Steps of Execution
# 1. Reading,Understanding and visualising the data
# 2. Preparing the data for modeling (test-train, rescaling etc)
# 3. Training the model
# 4. Residual analysis
# 5. Predictions and evaluation on the set

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score

import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Housing.csv')

# %% [markdown]
# ## This Section of Code will determine the Multiple Regression Model Through Manual Feature Elimination Approach

# %% [markdown]
# ## Step 1 :Reading,Understanding and visualising the data

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
# price               545 non-null int64
# area                545 non-null int64
# bedrooms            545 non-null int64
# bathrooms           545 non-null int64
# stories             545 non-null int64
# mainroad            545 non-null object
# guestroom           545 non-null object
# basement            545 non-null object
# hotwaterheating     545 non-null object
# airconditioning     545 non-null object
# parking             545 non-null int64
# prefarea            545 non-null object
# furnishingstatus    545 non-null object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
df.shape
# Out:
# (545, 13)

# %%
df.mainroad.unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
df.guestroom.unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df.basement.unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df.hotwaterheating.unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df.airconditioning.unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
df.prefarea.unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
df.furnishingstatus.unique()
# Out:
# array(['furnished', 'semi-furnished', 'unfurnished'], dtype=object)

# %%
# visualising the numeric
sns.pairplot(df)
plt.show()

# %%
# visualising the categorical variables
plt.subplots(figsize = (12,8))
plt.subplot(2,3,1)
sns.boxplot(df.mainroad,df.price)
plt.subplot(2,3,2)
sns.boxplot(df.guestroom,df.price)
plt.subplot(2,3,3)
sns.boxplot(df.basement,df.price)
plt.subplot(2,3,4)
sns.boxplot(df.hotwaterheating,df.price)
plt.subplot(2,3,5)
sns.boxplot(df.airconditioning,df.price)
plt.subplot(2,3,6)
sns.boxplot(df.furnishingstatus,df.price)

plt.show()

# %% [markdown]
# #### Convert categorical to numeric
# 1. Coverting binary vars to 1 and 0
# 2. Other categorical vars to dummy vars

# %%
variables = df.loc[:,(df.dtypes == object) & (df.columns != 'furnishingstatus')].columns

# %%
variables
# Out:
# Index(['mainroad', 'guestroom', 'basement', 'hotwaterheating',
#        'airconditioning', 'prefarea'],
#       dtype='object')

# %%
df[variables] = df[variables].apply(lambda x: x.map(lambda y:1 if y == 'yes' else 0))
#df[vairables] = df[vairables].apply(lambda x: x.map({'yes' : 1, 'no' : 0}))

# %%
df.furnishingstatus
# Out:
# 0           furnished
# 1           furnished
# 2      semi-furnished
# 3           furnished
# 4           furnished
#             ...
# 540       unfurnished
# 541    semi-furnished
# 542       unfurnished
# 543         furnished
# 544       unfurnished
# Name: furnishingstatus, Length: 545, dtype: object

# %%
#creating dummy variable for furnishingstatus
status = pd.get_dummies(df.furnishingstatus,drop_first = True)

# %%
status
# Out:
#      semi-furnished  unfurnished
# 0                 0            0
# 1                 0            0
# 2                 1            0
# 3                 0            0
# 4                 0            0
# ..              ...          ...
# 540               0            1
# 541               1            0
# 542               0            1
# 543               0            0
# 544               0            1
#
# [545 rows x 2 columns]

# %%
df = pd.concat([df,status],axis = 1)

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
df.drop('furnishingstatus',inplace = True,axis = 1)

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %% [markdown]
# ## Step 2 : Preparing the data for modeling (test-train, rescaling etc)

# %% [markdown]
# #### Split into Train and Test Dataset

# %%
'''X = df.loc[:,df.columns != 'price']
y = df.loc[:,'price']
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7, test_size = 0.3, random_state = 100)
'''
df_train, df_test = train_test_split(df, train_size = 0.7, random_state = 100)

# %% [markdown]
# #### Preprocessing : Rescaling the features, MinMax Function, Standardization

# %%
# 1. Instantiate an object
scaler = MinMaxScaler()
# we are not going to rescale 0 and 1
num_vars = ['area','bedrooms','bathrooms','stories','parking','price']

# 2. Fit on data

df_train[num_vars] = scaler.fit_transform(df_train[num_vars])

# %%
df_train
# Out:
#         price      area  bedrooms  bathrooms   stories  mainroad  guestroom  \
# 359  0.169697  0.155227       0.4        0.0  0.000000         1          0
# 19   0.615152  0.403379       0.4        0.5  0.333333         1          0
# 159  0.321212  0.115628       0.4        0.5  0.000000         1          1
# 35   0.548133  0.454417       0.4        0.5  1.000000         1          0
# 28   0.575758  0.538015       0.8        0.5  0.333333         1          0
# ..        ...       ...       ...        ...       ...       ...        ...
# 526  0.048485  0.118268       0.2        0.0  0.000000         1          0
# 53   0.484848  0.291623       0.4        0.5  1.000000         1          0
# 350  0.175758  0.139388       0.2        0.0  0.333333         1          0
# 79   0.424242  0.366420       0.4        0.5  0.666667         1          1
# 520  0.060606  0.516015       0.2        0.0  0.000000         1          0
#
# ...

# %% [markdown]
# ## Step 3: Training the Model

# %% [markdown]
# - Manual Method

# %%
plt.subplots(figsize = (35,25))
sns.heatmap(df_train.corr(),cmap = 'Greens',annot = True,)
plt.show()

# %%
X_train = df_train.loc[:,df.columns != 'price']
y_train = df_train.price

# %%
X_train.head()
# Out:
#          area  bedrooms  bathrooms   stories  mainroad  guestroom  basement  \
# 359  0.155227       0.4        0.0  0.000000         1          0         0
# 19   0.403379       0.4        0.5  0.333333         1          0         0
# 159  0.115628       0.4        0.5  0.000000         1          1         1
# 35   0.454417       0.4        0.5  1.000000         1          0         0
# 28   0.538015       0.8        0.5  0.333333         1          0         1
#
#      hotwaterheating  airconditioning   parking  prefarea  semi-furnished  \
# 359                0                0  0.333333         0               0
# 19                 0                1  0.333333         1               1
# 159                0                1  0.000000         0               0
# 35                 0                1  0.666667         0               0
# 28                 1                0  0.666667         0               0
#
#      unfurnished
# 359            1
# 19             0
# ...

# %%
y_train.head()
# Out:
# 359    0.169697
# 19     0.615152
# 159    0.321212
# 35     0.548133
# 28     0.575758
# Name: price, dtype: float64

# %% [markdown]
# - First statistically determine the significance of variables
# - Calculate VIF

# %% [markdown]
# #### Method 1 , Add variables one after the other and make decision on which are redundent and which are not

# %% [markdown]
# - So lets start with Area variable with target variable -Price, as these two have highest correlation compared to other variables

# %%
# add a constant if Statsmodel is been used
X_train_sm = sm.add_constant(X_train.area)

# create a first model
lr = sm.OLS(y_train, X_train_sm)

# fit
lr_model = lr.fit()

# params
lr_model.params

lr_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.283
# Model:                            OLS   Adj. R-squared:                  0.281
# Method:                 Least Squares   F-statistic:                     149.6
# Date:                Wed, 26 May 2021   Prob (F-statistic):           3.15e-29
# Time:                        13:50:27   Log-Likelihood:                 227.23
# No. Observations:                 381   AIC:                            -450.5
# Df Residuals:                     379   BIC:                            -442.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1269      0.013      9.853      0.000       0.102       0.152
# ...

# %%
# add anothervariable which has next higher correlation
X_train_sm = sm.add_constant(X_train[['area','bathrooms']])

# create a first model
lr = sm.OLS(y_train, X_train_sm)

# fit
lr_model = lr.fit()

# summary
lr_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.480
# Model:                            OLS   Adj. R-squared:                  0.477
# Method:                 Least Squares   F-statistic:                     174.1
# Date:                Wed, 26 May 2021   Prob (F-statistic):           2.51e-54
# Time:                        13:50:27   Log-Likelihood:                 288.24
# No. Observations:                 381   AIC:                            -570.5
# Df Residuals:                     378   BIC:                            -558.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1046      0.011      9.384      0.000       0.083       0.127
# ...

# %%
# add anothervariable which has next higher correlation
X_train_sm = sm.add_constant(X_train[['area','bathrooms','bedrooms']])

# create a first model
lr = sm.OLS(y_train, X_train_sm)

# fit
lr_model = lr.fit()

# summary
lr_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.505
# Model:                            OLS   Adj. R-squared:                  0.501
# Method:                 Least Squares   F-statistic:                     128.2
# Date:                Wed, 26 May 2021   Prob (F-statistic):           3.12e-57
# Time:                        13:50:27   Log-Likelihood:                 297.76
# No. Observations:                 381   AIC:                            -587.5
# Df Residuals:                     377   BIC:                            -571.7
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0414      0.018      2.292      0.022       0.006       0.077
# ...

# %% [markdown]
# ###### Similarly we could add some more variables and determine the reduntdant variables

# %% [markdown]
# #### Method 2
#
# #### Adding All variables to the Model and then removing least significant variable through iterative process

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 14 columns):
# price              545 non-null int64
# area               545 non-null int64
# bedrooms           545 non-null int64
# bathrooms          545 non-null int64
# stories            545 non-null int64
# mainroad           545 non-null int64
# guestroom          545 non-null int64
# basement           545 non-null int64
# hotwaterheating    545 non-null int64
# airconditioning    545 non-null int64
# parking            545 non-null int64
# prefarea           545 non-null int64
# semi-furnished     545 non-null uint8
# unfurnished        545 non-null uint8
# dtypes: int64(12), uint8(2)
# memory usage: 52.3 KB

# %%
# add anothervariable which has next higher correlation
X_train_sm = sm.add_constant(X_train)

# create a first model
lr = sm.OLS(y_train, X_train_sm)

# fit
lr_model = lr.fit()

# summary
lr_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.681
# Model:                            OLS   Adj. R-squared:                  0.670
# Method:                 Least Squares   F-statistic:                     60.40
# Date:                Wed, 26 May 2021   Prob (F-statistic):           8.83e-83
# Time:                        13:50:27   Log-Likelihood:                 381.79
# No. Observations:                 381   AIC:                            -735.6
# Df Residuals:                     367   BIC:                            -680.4
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %% [markdown]
# - First we will look at the significance of the variables (p-values)
# - VIF

# %%
vif = pd.DataFrame()
vif['Features'] = X_train.columns
vif['VIF'] = [variance_inflation_factor(X_train.values,i) for i in range(X_train.shape[1])]
vif['VIF'] = round(vif['VIF'],2)
vif = vif.sort_values(by = 'VIF', ascending = False)
vif
# Out:
#            Features   VIF
# 1          bedrooms  7.33
# 4          mainroad  6.02
# 0              area  4.67
# 3           stories  2.70
# 11   semi-furnished  2.19
# 9           parking  2.12
# 6          basement  2.02
# 12      unfurnished  1.82
# 8   airconditioning  1.77
# 2         bathrooms  1.67
# 10         prefarea  1.51
# 5         guestroom  1.47
# 7   hotwaterheating  1.14

# %% [markdown]
# we could have :
# - High p-value, high VIF: We remove them
# - High & Low
#     - (High p, low VIF) : Remove these first
#     - (Low p, high VIF) : Remove these after the above one
# - Low p-value, low VIF : keep these variables

# %% [markdown]
# ###### Remove semi-furnished variable because it has high p-value

# %%
X_train.drop('semi-furnished',inplace = True,axis = 1)

# %%
# add anothervariable which has next higher correlation
X_train_sm = sm.add_constant(X_train)

# create a first model
lr = sm.OLS(y_train, X_train_sm)

# fit
lr_model = lr.fit()

# summary
lr_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.681
# Model:                            OLS   Adj. R-squared:                  0.671
# Method:                 Least Squares   F-statistic:                     65.61
# Date:                Wed, 26 May 2021   Prob (F-statistic):           1.07e-83
# Time:                        13:50:27   Log-Likelihood:                 381.79
# No. Observations:                 381   AIC:                            -737.6
# Df Residuals:                     368   BIC:                            -686.3
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
vif = pd.DataFrame()
vif['Features'] = X_train.columns
vif['VIF'] = [variance_inflation_factor(X_train.values,i) for i in range(X_train.shape[1])]
vif['VIF'] = round(vif['VIF'],2)
vif = vif.sort_values(by = 'VIF', ascending = False)
vif
# Out:
#            Features   VIF
# 1          bedrooms  6.59
# 4          mainroad  5.68
# 0              area  4.67
# 3           stories  2.69
# 9           parking  2.12
# 6          basement  2.01
# 8   airconditioning  1.77
# 2         bathrooms  1.67
# 10         prefarea  1.51
# 5         guestroom  1.47
# 11      unfurnished  1.40
# 7   hotwaterheating  1.14

# %% [markdown]
# ###### Now Remove Bedrooms as it has higher p-value as well as high VIF compared to other modules

# %%
X_train.drop('bedrooms',inplace = True,axis = 1)

# %%
# add anothervariable which has next higher correlation
X_train_sm = sm.add_constant(X_train)

# create a first model
lr = sm.OLS(y_train, X_train_sm)

# fit
lr_model = lr.fit()

# summary
lr_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.680
# Model:                            OLS   Adj. R-squared:                  0.671
# Method:                 Least Squares   F-statistic:                     71.31
# Date:                Wed, 26 May 2021   Prob (F-statistic):           2.73e-84
# Time:                        13:50:28   Log-Likelihood:                 380.96
# No. Observations:                 381   AIC:                            -737.9
# Df Residuals:                     369   BIC:                            -690.6
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
vif = pd.DataFrame()
vif['Features'] = X_train.columns
vif['VIF'] = [variance_inflation_factor(X_train.values,i) for i in range(X_train.shape[1])]
vif['VIF'] = round(vif['VIF'],2)
vif = vif.sort_values(by = 'VIF', ascending = False)
vif
# Out:
#            Features   VIF
# 3          mainroad  4.79
# 0              area  4.55
# 2           stories  2.23
# 8           parking  2.10
# 5          basement  1.87
# 7   airconditioning  1.76
# 1         bathrooms  1.61
# 9          prefarea  1.50
# 4         guestroom  1.46
# 10      unfurnished  1.33
# 6   hotwaterheating  1.12

# %% [markdown]
# ## Step 4: Residual Analysis

# %%
y_train_pred = lr_model.predict(X_train_sm)

# %%
res = y_train - y_train_pred
sns.distplot(res)

# %% [markdown]
# - it is observed that the residuals are normally distributed

# %% [markdown]
# ## Step 5: Prediction and Evaluation on the Test Dataset

# %%
# 1. Instantiate an object

# we are not going to rescale 0 and 1
num_vars = ['area','bedrooms','bathrooms','stories','parking','price']

# 2. Transform on data

df_test[num_vars] = scaler.transform(df_test[num_vars])
df_test.head()
# we only fit and transform for train dataset
# but we only transform for the test dataset
# Out:
#         price      area  bedrooms  bathrooms   stories  mainroad  guestroom  \
# 265  0.229697  0.091869       0.4        0.0  0.333333         1          0
# 54   0.484848  0.366420       0.4        0.5  0.333333         1          1
# 171  0.303030  0.742080       0.4        0.0  0.000000         1          0
# 244  0.242424  0.306582       0.4        0.0  0.333333         1          1
# 268  0.227879  0.274023       0.6        0.0  0.333333         1          0
#
#      basement  hotwaterheating  airconditioning   parking  prefarea  \
# 265         0                0                0  0.000000         1
# 54          0                0                1  0.333333         0
# 171         0                0                0  0.333333         1
# 244         1                0                0  0.000000         1
# 268         0                0                1  0.000000         0
#
#      semi-furnished  unfurnished
# 265               1            0
# ...

# %%
df_test.describe()
# Out:
#             price        area    bedrooms   bathrooms     stories    mainroad  \
# count  164.000000  164.000000  164.000000  164.000000  164.000000  164.000000
# mean     0.263176    0.298548    0.408537    0.158537    0.268293    0.865854
# std      0.172077    0.211922    0.147537    0.281081    0.276007    0.341853
# min      0.006061   -0.016367    0.200000    0.000000    0.000000    0.000000
# 25%      0.142424    0.148011    0.400000    0.000000    0.000000    1.000000
# 50%      0.226061    0.259724    0.400000    0.000000    0.333333    1.000000
# 75%      0.346970    0.397439    0.400000    0.500000    0.333333    1.000000
# max      0.909091    1.263992    0.800000    1.500000    1.000000    1.000000
#
#         guestroom    basement  hotwaterheating  airconditioning     parking  \
# count  164.000000  164.000000       164.000000       164.000000  164.000000
# mean     0.195122    0.347561         0.030488         0.353659    0.205285
# ...

# %% [markdown]
# - why the max values are not 1 is because we had used the scaler to fit the values for the training set, and then transform, similarly we had just transformed the values in the test set by the using the same min and max values of the training set. hence we dont fit the data for the test set

# %%
X_test = df_test.loc[:,df.columns != 'price']
y_test = df_test.price

#y_test = df_test.pop('price')
#X_test = df_test

# %%
X_test_sm = sm.add_constant(X_test)
X_test_sm.head()
# Out:
#      const      area  bedrooms  bathrooms   stories  mainroad  guestroom  \
# 265    1.0  0.091869       0.4        0.0  0.333333         1          0
# 54     1.0  0.366420       0.4        0.5  0.333333         1          1
# 171    1.0  0.742080       0.4        0.0  0.000000         1          0
# 244    1.0  0.306582       0.4        0.0  0.333333         1          1
# 268    1.0  0.274023       0.6        0.0  0.333333         1          0
#
#      basement  hotwaterheating  airconditioning   parking  prefarea  \
# 265         0                0                0  0.000000         1
# 54          0                0                1  0.333333         0
# 171         0                0                0  0.333333         1
# 244         1                0                0  0.000000         1
# 268         0                0                1  0.000000         0
#
#      semi-furnished  unfurnished
# 265               1            0
# 54                1            0
# ...

# %%
X_test_sm.drop(['bedrooms','semi-furnished'],inplace = True, axis = 1)

# %%
y_test_pred = lr_model.predict(X_test_sm)

# %%
#evalaute
r2_score(y_true = y_test, y_pred = y_test_pred)
# Out:
# 0.6713505684480789

# %%
lr_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.680
# Model:                            OLS   Adj. R-squared:                  0.671
# Method:                 Least Squares   F-statistic:                     71.31
# Date:                Wed, 26 May 2021   Prob (F-statistic):           2.73e-84
# Time:                        13:50:28   Log-Likelihood:                 380.96
# No. Observations:                 381   AIC:                            -737.9
# Df Residuals:                     369   BIC:                            -690.6
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## This Section of Code will determine the Multiple Regression Model Through Automated-Manual Feature Elimination Approach

# %% [markdown]
# ### The first step is same

# %% [markdown]
# ## Step 2: Preparing the Data for Modeling

# %%
df_train, df_test = train_test_split(df, train_size = 0.7, random_state = 100)

# %%
# 1. Instantiate an object
scaler = MinMaxScaler()
# we are not going to rescale 0 and 1
num_vars = ['area','bedrooms','bathrooms','stories','parking','price']

# 2. Fit on data

df_train[num_vars] = scaler.fit_transform(df_train[num_vars])

# %%
df_train.head()
# Out:
#         price      area  bedrooms  bathrooms   stories  mainroad  guestroom  \
# 359  0.169697  0.155227       0.4        0.0  0.000000         1          0
# 19   0.615152  0.403379       0.4        0.5  0.333333         1          0
# 159  0.321212  0.115628       0.4        0.5  0.000000         1          1
# 35   0.548133  0.454417       0.4        0.5  1.000000         1          0
# 28   0.575758  0.538015       0.8        0.5  0.333333         1          0
#
#      basement  hotwaterheating  airconditioning   parking  prefarea  \
# 359         0                0                0  0.333333         0
# 19          0                0                1  0.333333         1
# 159         1                0                1  0.000000         0
# 35          0                0                1  0.666667         0
# 28          1                1                0  0.666667         0
#
#      semi-furnished  unfurnished
# 359               0            1
# ...

# %% [markdown]
# ## Step 3: Training the Model

# %% [markdown]
# ##### Recursive feature Elimination

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# %%
X_train = df_train.loc[:,df.columns != 'price']
y_train = df_train.price

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
rfe = RFE(lr,10)
rfe = rfe.fit(X_train, y_train)

# %%
list(zip(X_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('area', True, 1),
#  ('bedrooms', True, 1),
#  ('bathrooms', True, 1),
#  ('stories', True, 1),
#  ('mainroad', True, 1),
#  ('guestroom', True, 1),
#  ('basement', False, 3),
#  ('hotwaterheating', True, 1),
#  ('airconditioning', True, 1),
#  ('parking', True, 1),
#  ('prefarea', True, 1),
#  ('semi-furnished', False, 4),
#  ('unfurnished', False, 2)]

# %%
columns = X_train.columns[rfe.support_]
columns
# Out:
# Index(['area', 'bedrooms', 'bathrooms', 'stories', 'mainroad', 'guestroom',
#        'hotwaterheating', 'airconditioning', 'parking', 'prefarea'],
#       dtype='object')

# %% [markdown]
# ##### Building the model using statsmodel

# %%
X_train_rfe = X_train[columns]
X_train_rfe = sm.add_constant(X_train_rfe)
lm = sm.OLS(y_train,X_train_rfe).fit()

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.669
# Model:                            OLS   Adj. R-squared:                  0.660
# Method:                 Least Squares   F-statistic:                     74.89
# Date:                Wed, 26 May 2021   Prob (F-statistic):           1.28e-82
# Time:                        13:50:29   Log-Likelihood:                 374.65
# No. Observations:                 381   AIC:                            -727.3
# Df Residuals:                     370   BIC:                            -683.9
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %% [markdown]
# ###### as it is observed that the variable bedrooms have high p-value hence treated to be insignificant

# %%
X_train_new = X_train_rfe.drop(["bedrooms"], axis = 1)

# %%
X_train_lm = sm.add_constant(X_train_new)

# %%
lm = sm.OLS(y_train,X_train_lm).fit()

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.666
# Model:                            OLS   Adj. R-squared:                  0.658
# Method:                 Least Squares   F-statistic:                     82.37
# Date:                Wed, 26 May 2021   Prob (F-statistic):           6.67e-83
# Time:                        13:50:29   Log-Likelihood:                 373.00
# No. Observations:                 381   AIC:                            -726.0
# Df Residuals:                     371   BIC:                            -686.6
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
vif = pd.DataFrame()
X = X_train_new.drop('const',axis = 1)
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#           Features   VIF
# 0             area  4.52
# 3         mainroad  4.26
# 2          stories  2.12
# 7          parking  2.10
# 6  airconditioning  1.75
# 1        bathrooms  1.58
# 8         prefarea  1.47
# 4        guestroom  1.30
# 5  hotwaterheating  1.12

# %% [markdown]
# ## Step 4: Residual Analysis

# %%
y_train_price = lm.predict(X_train_lm)

# %%
# Plot the histogram of the error terms
fig = plt.figure()
sns.distplot((y_train - y_train_price), bins = 20)
fig.suptitle('Error Terms', fontsize = 20)                  # Plot heading 
plt.xlabel('Errors', fontsize = 18)                         # X-label
# Out:
# Text(0.5, 0, 'Errors')

# %% [markdown]
# ## Step 5: Prediction and Evaluation

# %%
num_vars = ['area', 'bedrooms', 'bathrooms', 'stories', 'parking','price']

# %%
df_test[num_vars] = scaler.transform(df_test[num_vars])

# %%
#### Dividing into X_test and y_test

y_test = df_test.pop('price')
X_test = df_test

# %%
# Now let's use our model to make predictions.
X_train_new.drop('const',inplace = True,axis = 1)
# Creating X_test_new dataframe by dropping variables from X_test
X_test_new = X_test[X_train_new.columns]

# Adding a constant variable 
X_test_new = sm.add_constant(X_test_new)

# Making predictions
y_pred = lm.predict(X_test_new)

# %%
## Model Evaluation

# Plotting y_test and y_pred to understand the spread.
fig = plt.figure()
plt.scatter(y_test,y_pred)
fig.suptitle('y_test vs y_pred', fontsize=20)              # Plot heading 
plt.xlabel('y_test', fontsize=18)                          # X-label
plt.ylabel('y_pred', fontsize=16)                          # Y-label
# Out:
# Text(0, 0.5, 'y_pred')
